# %%
#Import packages

import pandas as pd
import numpy as np
from googletrans import Translator
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %%
#Read in .csv
data = pd.read_csv('translated_data.csv')
data = pd.DataFrame(data)

# %% [markdown]
# ## Exploring the data

# %%
#Overview of dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1917 entries, 0 to 1916
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1917 non-null   int64
#  1   name            1917 non-null   object
#  2   price           1917 non-null   object
#  3   location        1917 non-null   object
#  4   offerer         1917 non-null   object
#  5   link            1917 non-null   object
#  6   id              1917 non-null   int64
#  7   img_url         1665 non-null   object
#  8   listing_url     1917 non-null   object
#  9   description     1917 non-null   object
#  10  year            1917 non-null   int64
#  11  manufacturer    1917 non-null   object
#  12  model           1909 non-null   object
#  13  class           1917 non-null   object
#  14  length          1917 non-null   object
#  15  fuel            1797 non-null   object
#  16  hull_material   1917 non-null   object
#  17  hull_shape      421 non-null    object
#  18  hull_id_number  127 non-null    object
#  19  hull_warranty   26 non-null     object
# dtypes: int64(3), object(17)
# memory usage: 299.7+ KB

# %%
data.T
# Out:
#                                                              0     \
# Unnamed: 0                                                      0
# name            1976 Ketch Baarda Zeegrundel1976 Ketch Baarda ...
# price                                                    24.500 €
# location                                  Dinteloord, Niederlande
# offerer                                            Sealion Yachts
# link                  /boot/1976-ketch-baarda-zeegrundel-8222682/
# id                                                        8222682
# img_url         https://images.boatsgroup.com/resize/1/26/82/8...
# listing_url     https://www.boot24.com/boot/1976-ketch-baarda-...
# description     Algemeen: De Zeegrundel is een oorspronkelijk ...
# year                                                         1976
# manufacturer                                                Ketch
# model                                           Baarda Zeegrundel
# class                                             Barge sail boat
# length                                                       900m
# fuel                                                       Diesel
# hull_material                                               Steel
# hull_shape                                                    NaN
# hull_id_number                                                NaN
# hull_warranty                                                 NaN
#
#                                                              1     \
# Unnamed: 0                                                      1
# name                             1979 Dufour 28001979 Dufour 2800
# price                                                     9.900 €
# location                                  Greifswald, Deutschland
# offerer                                        Privater Verkäufer
# link                              /boot/1979-dufour-2800-8457402/
# id                                                        8457402
# img_url                                                       NaN
# listing_url     https://www.boot24.com/boot/1979-dufour-2800-8...
# description     Verkaufe eine gut erhaltene und ausgestattete ...
# year                                                         1979
# manufacturer                                               Dufour
# model                                                        2800
# class                                    Sailing boats with cabin
# length                                                        83m
# fuel                                                       Diesel
# hull_material                              Fiberglass / Polyester
# hull_shape                                                    NaN
# hull_id_number                                                NaN
# hull_warranty                                                 NaN
#
#                                                              2     \
# Unnamed: 0                                                      2
# name            2010 Van der Graaf Classic Schooner2010 Van de...
# price                                                12.000.000 €
# location                      Contact De Valk Antibes, Frankreich
# offerer                                         De Valk Group B.V
# link            /boot/2010-van-der-graaf-classic-schooner-7936...
# id                                                        7936534
# img_url                                                       NaN
# listing_url     https://www.boot24.com/boot/2010-van-der-graaf...
# description     Model: VAN DER GRAAF CLASSIC SCHOONER Type: sa...
# year                                                         2010
# manufacturer                                        Van der Graaf
# model                                            Classic Schooner
# class                                                 Sloop boats
# length                                                     65,84m
# fuel                                                       Diesel
# hull_material                                               Steel
# hull_shape                                                    NaN
# hull_id_number                                                NaN
# hull_warranty                                                 NaN
#
#                                                              3     \
# Unnamed: 0                                                      3
# name            2010 Custom Van Der Graaf BV Schooner2010 Cust...
# price                                                12.000.000 €
# location                                         IMPERIA, Italien
# offerer                            Bernard Gallay Yacht Brokerage
# link            /boot/2010-custom-van-der-graaf-bv-schooner-67...
# id                                                        6751543
# img_url         https://images.boatsgroup.com/resize/1/15/43/6...
# listing_url     https://www.boot24.com/boot/2010-custom-van-de...
# description     Price On Application\n \nThe current ATLANTIC ...
# year                                                         2010
# manufacturer                                               Custom
# model                                   Van Der Graaf BV Schooner
# class                                                     Cleaner
# length                                                     64,50m
# fuel                                                       Diesel
# hull_material                                               Steel
# hull_shape                                                    NaN
# hull_id_number                                                NaN
# hull_warranty                                                 NaN
#
#                                                              4     \
# Unnamed: 0                                                      4
# name               2008 Custom Build Gulet2008 Custom Build Gulet
# price                                                 5.000.000 €
# location                                                   Türkei
# offerer                                                Gino Group
# link                        /boot/2008-custom-build-gulet-469955/
# id                                                         469955
# img_url         https://images.boatsgroup.com/resize/1/99/55/4...
# listing_url     https://www.boot24.com/boot/2008-custom-build-...
# description     A beautiful 43m Gulet classic luxury style bui...
# year                                                         2008
# manufacturer                                         Custom Build
# model                                                       Gulet
# class                                              Sailing yachts
# length                                                     42,98m
# fuel                                                       Diesel
# hull_material                                                Wood
# hull_shape                                                    NaN
# hull_id_number                                                NaN
# hull_warranty                                                 NaN
#
#                                                              5     \
# Unnamed: 0                                                      5
# name                             2025 Sunreef 1402025 Sunreef 140
# price                                           Preis auf Anfrage
# location                                            Gdansk, Polen
# offerer                                                 S6 Marine
# link                              /boot/2025-sunreef-140-8164809/
# id                                                        8164809
# img_url         https://images.boatsgroup.com/resize/1/48/9/81...
# listing_url     https://www.boot24.com/boot/2025-sunreef-140-8...
# description     The Sunreef 140 is a multihull superyacht boas...
# year                                                         2025
# manufacturer                                              Sunreef
# model                                                         140
# class                                                   Catamaran
# length                                                     42,67m
# fuel                                                        Other
# hull_material                                           Composite
# hull_shape                                              Catamaran
# hull_id_number                                                NaN
# hull_warranty                                                 NaN
#
#                                                              6     \
# Unnamed: 0                                                      6
# name                         2015 Bodrum Custom2015 Bodrum Custom
# price                                                 7.950.000 €
# location                             Sud de la france, Frankreich
# offerer                                     SARL YACHTSIDE MONACO
# link                            /boot/2015-bodrum-custom-8404683/
# id                                                        8404683
# img_url         https://images.boatsgroup.com/resize/1/46/83/8...
# listing_url     https://www.boot24.com/boot/2015-bodrum-custom...
# description     Make: BODRUM Model: Custom Year: 2015Mehr anze...
# year                                                         2015
# manufacturer                                               Bodrum
# model                                                      Custom
# class                                           Other (sailboats)
# length                                                     39,90m
# fuel                                                       Diesel
# hull_material                                        Ferro-cement
# hull_shape                                                    NaN
# hull_id_number                                                NaN
# hull_warranty                                                 NaN
#
#                                                              7     \
# Unnamed: 0                                                      7
# name            1986 Fjellstrand DSC Passenger Catamaran1986 F...
# price                                                   987.000 €
# location                      Contact De Valk Corfu, Griechenland
# offerer                                         De Valk Group B.V
# link            /boot/1986-fjellstrand-dsc-passenger-catamaran...
# id                                                        7937781
# img_url         https://images.boatsgroup.com/resize/1/77/81/7...
# listing_url     https://www.boot24.com/boot/1986-fjellstrand-d...
# description     Model: FJELLSTRAND DSC PASSENGER CATAMARAN Typ...
# year                                                         1986
# manufacturer                                          Fjellstrand
# model                                     DSC Passenger Catamaran
# class                                    Catamarans and trimarans
# length                                                     38,80m
# fuel                                                       Diesel
# hull_material                                            Aluminum
# hull_shape                                                  Other
# hull_id_number                                                NaN
# hull_warranty                                                 NaN
#
#                                                              8     \
# Unnamed: 0                                                      8
# name            1911 William Fife & Sons 38Meter1911 William F...
# price                                                 3.500.000 €
# location                                   London, Greater London
# offerer                           Boats & Barcos Mediterráneos SL
# link              /boot/1911-william-fife-$-sons-38meter-6081675/
# id                                                        6081675
# img_url         https://images.boatsgroup.com/resize/1/16/75/6...
# listing_url     https://www.boot24.com/boot/1911-william-fife-...
# description     Designed and built by William Fife, "Mariquita...
# year                                                         1911
# manufacturer                                         William Fife
# model                                              & Sons 38Meter
# class                                           Classic sailboats
# length                                                     38,10m
# fuel                                                       Diesel
# hull_material                                                Wood
# hull_shape                                                    NaN
# hull_id_number                                                NaN
# hull_warranty                                                 NaN
#
#                                                              9     ...  \
# Unnamed: 0                                                      9  ...
# name                 2007 Schooner Eldorado2007 Schooner Eldorado  ...
# price                                                 1.300.000 €  ...
# location                   Contact De Valk Amsterdam, Deutschland  ...
# offerer                                         De Valk Group B.V  ...
# link                        /boot/2007-schooner-eldorado-7936739/  ...
# id                                                        7936739  ...
# img_url         https://images.boatsgroup.com/resize/1/67/39/7...  ...
# listing_url     https://www.boot24.com/boot/2007-schooner-eldo...  ...
# description     Model: SCHOONER ELDORADO Type: sailing yacht L...  ...
# year                                                         2007  ...
# manufacturer                                             Schooner  ...
# model                                                    Eldorado  ...
# class                                                 Sloop boats  ...
# length                                                        38m  ...
# fuel                                                       Diesel  ...
# hull_material                                               Steel  ...
# hull_shape                                                    NaN  ...
# hull_id_number                                                NaN  ...
# hull_warranty                                                 NaN  ...
#
#                                                              1907  \
# Unnamed: 0                                                   1907
# name                         1965 Flying Junior1965 Flying Junior
# price                                                       950 €
# location                                              Niederlande
# offerer                               Jachtbemiddeling Sneekerhof
# link                            /boot/1965-flying-junior-8121036/
# id                                                        8121036
# img_url         https://images.boatsgroup.com/resize/1/10/36/8...
# listing_url     https://www.boot24.com/boot/1965-flying-junior...
# description     Open sailboat with excellent sailing character...
# year                                                         1965
# manufacturer                                               Flying
# model                                                      Junior
# class                                           Other (sailboats)
# length                                                      4,03m
# fuel                                                          NaN
# hull_material                              Fiberglass / Polyester
# hull_shape                                                    NaN
# hull_id_number                                                NaN
# hull_warranty                                                 NaN
#
#                                                              1908  \
# Unnamed: 0                                                   1908
# name            2021 unbekannt 12-fuß-dinghy2021 unbekannt 12-...
# price                                                    12.500 €
# location                                    Augsburg, Deutschland
# offerer                                        Privater Verkäufer
# link                /boot/2021-unbekannt-12--fu---dinghy-8431689/
# id                                                        8431689
# img_url                                                       NaN
# listing_url     https://www.boot24.com/boot/2021-unbekannt-12-...
# description     Das Gesamtpaket umfasst: Rumpf (GFK) mit Holz-...
# year                                                         2021
# manufacturer                                            unbekannt
# model                                               12-fuß-dinghy
# class                                Dinghies and dinghy cruisers
# length                                                      3,67m
# fuel                                                          NaN
# hull_material                                           Composite
# hull_shape                                                    NaN
# hull_id_number                                                NaN
# hull_warranty                                                 NaN
#
#                                                              1909  \
# Unnamed: 0                                                   1909
# name            2010 Teja wooden Boats 12-Fuß Dingi -VERKAUFT-...
# price                                                     9.900 €
# location                                      Alster, Deutschland
# offerer                                      Nordic Yachting e.K.
# link            /boot/2010-teja-wooden-boats-12--fu-dingi---ve...
# id                                                        8416222
# img_url         https://images.boatsgroup.com/resize/1/62/22/8...
# listing_url     https://www.boot24.com/boot/2010-teja-wooden-b...
# description     Naturlackiertes 12-Fuß Dinghy von Teja Woodenb...
# year                                                         2010
# manufacturer                                    Teja wooden Boats
# model                                     12-Fuß Dingi -VERKAUFT-
# class                                Dinghies and dinghy cruisers
# length                                                      3,66m
# fuel                                                          NaN
# hull_material                                                Wood
# hull_shape                                                    NaN
# hull_id_number                                                NaN
# hull_warranty                                                 NaN
#
#                                                              1910  \
# Unnamed: 0                                                   1910
# name                               1850 Topper 3401850 Topper 340
# price                                                        25 €
# location                             Dinteloord (NL), Niederlande
# offerer                                           Bootveiling.com
# link                               /boot/1850-topper-340-8507924/
# id                                                        8507924
# img_url         https://images.boatsgroup.com/resize/1/79/24/8...
# listing_url     https://www.boot24.com/boot/1850-topper-340-85...
# description     Een Topper in de online veiling. Iedereen kan ...
# year                                                         1850
# manufacturer                                               Topper
# model                                                         340
# class                                                 Sloop boats
# length                                                      3,40m
# fuel                                                          NaN
# hull_material                                     Other materials
# hull_shape                                                    NaN
# hull_id_number                                                NaN
# hull_warranty                                                 NaN
#
#                                                              1911  \
# Unnamed: 0                                                   1911
# name                 2022 MiniCat 310 Sport2022 MiniCat 310 Sport
# price                                                     4.520 €
# location                                              Deutschland
# offerer                                           Steinkämper GbR
# link                        /boot/2022-minicat-310-sport-8412712/
# id                                                        8412712
# img_url         https://images.boatsgroup.com/resize/1/27/12/8...
# listing_url     https://www.boot24.com/boot/2022-minicat-310-s...
# description     Jetzt in der neuen 2022er Version, 5 kg leicht...
# year                                                         2022
# manufacturer                                              MiniCat
# model                                                   310 Sport
# class                                           Other (sailboats)
# length                                                      3,10m
# fuel                                                          NaN
# hull_material                                            Aluminum
# hull_shape                                                    NaN
# hull_id_number                                                NaN
# hull_warranty                                                 NaN
#
#                                                              1912  \
# Unnamed: 0                                                   1912
# name                         2022 MiniCat GUPPY2022 MiniCat GUPPY
# price                                                     3.200 €
# location                                              Deutschland
# offerer                                           Steinkämper GbR
# link                            /boot/2022-minicat-guppy-8412713/
# id                                                        8412713
# img_url         https://images.boatsgroup.com/resize/1/27/13/8...
# listing_url     https://www.boot24.com/boot/2022-minicat-guppy...
# description     Neues Modell Minicat GUPPY – kompakter geht es...
# year                                                         2022
# manufacturer                                              MiniCat
# model                                                       GUPPY
# class                                           Other (sailboats)
# length                                                         3m
# fuel                                                          NaN
# hull_material                                            Aluminum
# hull_shape                                                    NaN
# hull_id_number                                                NaN
# hull_warranty                                                 NaN
#
#                                                              1913  \
# Unnamed: 0                                                   1913
# name            2022 Williams Jet Tenders Ersatzschlauch2022 W...
# price                                                     3.600 €
# location                             Worms , Rhineland-Palatinate
# offerer                                      Allegro Handels GmbH
# link            /boot/2022-williams-jet-tenders-ersatzschlauch...
# id                                                        8483214
# img_url         https://images.boatsgroup.com/resize/1/32/14/8...
# listing_url     https://www.boot24.com/boot/2022-williams-jet-...
# description     Ersatzschlauch für Schlauchboot Turbojet 285, ...
# year                                                         2022
# manufacturer                                 Williams Jet Tenders
# model                                              Ersatzschlauch
# class                                           Other (sailboats)
# length                                                      2,89m
# fuel                                                        Other
# hull_material                                       PVC (Plastic)
# hull_shape                                                    NaN
# hull_id_number                                                NaN
# hull_warranty                                                 NaN
#
#                                                              1914  \
# Unnamed: 0                                                   1914
# name                           2014 Bic Open Bic2014 Bic Open Bic
# price                                                     3.099 €
# location                                           Edersee, Hesse
# offerer                                 Ship-Shop Rehbach-Edersee
# link                             /boot/2014-bic-open-bic-8398460/
# id                                                        8398460
# img_url         https://images.boatsgroup.com/resize/1/84/60/8...
# listing_url     https://www.boot24.com/boot/2014-bic-open-bic-...
# description     nur noch 2 Boote vorrätig Bj 2019\n Probesegel...
# year                                                         2014
# manufacturer                                                  Bic
# model                                                    Open Bic
# class                                              Sailing yachts
# length                                                      2,75m
# fuel                                                          NaN
# hull_material                                     Other materials
# hull_shape                                                    NaN
# hull_id_number                                                NaN
# hull_warranty                                                 NaN
#
#                                                              1915  \
# Unnamed: 0                                                   1915
# name            1986 Sailboat Zuanelli 25 1986 Sailboat Zuanel...
# price                                                     7.000 €
# location                                                  Italien
# offerer                                           Pollini Nautica
# link                     /boot/1986-sailboat-zuanelli-25-7391596/
# id                                                        7391596
# img_url         https://images.boatsgroup.com/resize/1/15/96/7...
# listing_url     https://www.boot24.com/boot/1986-sailboat-zuan...
# description           1986 Sailboat Zuanelli 25 nullMehr anzeigen
# year                                                         1986
# manufacturer                                 Sailboat Zuanelli 25
# model                                                         NaN
# class                                           Other (sailboats)
# length                                                      2,52m
# fuel                                                          NaN
# hull_material                                     Other materials
# hull_shape                                                  Other
# hull_id_number                                                NaN
# hull_warranty                                                 NaN
#
#                                                              1916
# Unnamed: 0                                                   1916
# name            1850 Botenkar Incl. 17 Stallingsbokken1850 Bot...
# price                                                     2.500 €
# location                             Dinteloord (NL), Niederlande
# offerer                                           Bootveiling.com
# link            /boot/1850-botenkar-incl.-17-stallingsbokken-8...
# id                                                        8505216
# img_url         https://images.boatsgroup.com/resize/1/52/16/8...
# listing_url     https://www.boot24.com/boot/1850-botenkar-incl...
# description     Een Botenkar Incl. 17 Stallingsbokken in de on...
# year                                                         1850
# manufacturer                                             Botenkar
# model                                    Incl. 17 Stallingsbokken
# class                                                 Sloop boats
# length                                                      2,50m
# fuel                                                          NaN
# hull_material                                               Steel
# hull_shape                                                    NaN
# hull_id_number                                                NaN
# hull_warranty                                                 NaN
#
# [20 rows x 1917 columns]

# %%
#Look at first few rows
data.head()
# Out:
#    Unnamed: 0                                               name  \
# 0           0  1976 Ketch Baarda Zeegrundel1976 Ketch Baarda ...
# 1           1                   1979 Dufour 28001979 Dufour 2800
# 2           2  2010 Van der Graaf Classic Schooner2010 Van de...
# 3           3  2010 Custom Van Der Graaf BV Schooner2010 Cust...
# 4           4     2008 Custom Build Gulet2008 Custom Build Gulet
#
#           price                             location  \
# 0      24.500 €              Dinteloord, Niederlande
# 1       9.900 €              Greifswald, Deutschland
# 2  12.000.000 €  Contact De Valk Antibes, Frankreich
# 3  12.000.000 €                     IMPERIA, Italien
# 4   5.000.000 €                               Türkei
#
#                           offerer  \
# 0                  Sealion Yachts
# 1              Privater Verkäufer
# 2               De Valk Group B.V
# 3  Bernard Gallay Yacht Brokerage
# 4                      Gino Group
#
#                                                 link       id  \
# 0        /boot/1976-ketch-baarda-zeegrundel-8222682/  8222682
# 1                    /boot/1979-dufour-2800-8457402/  8457402
# 2  /boot/2010-van-der-graaf-classic-schooner-7936...  7936534
# 3  /boot/2010-custom-van-der-graaf-bv-schooner-67...  6751543
# 4              /boot/2008-custom-build-gulet-469955/   469955
#
#                                              img_url  \
# 0  https://images.boatsgroup.com/resize/1/26/82/8...
# 1                                                NaN
# 2                                                NaN
# 3  https://images.boatsgroup.com/resize/1/15/43/6...
# 4  https://images.boatsgroup.com/resize/1/99/55/4...
#
#                                          listing_url  \
# 0  https://www.boot24.com/boot/1976-ketch-baarda-...
# 1  https://www.boot24.com/boot/1979-dufour-2800-8...
# 2  https://www.boot24.com/boot/2010-van-der-graaf...
# 3  https://www.boot24.com/boot/2010-custom-van-de...
# 4  https://www.boot24.com/boot/2008-custom-build-...
#
#                                          description  year   manufacturer  \
# 0  Algemeen: De Zeegrundel is een oorspronkelijk ...  1976          Ketch
# 1  Verkaufe eine gut erhaltene und ausgestattete ...  1979         Dufour
# 2  Model: VAN DER GRAAF CLASSIC SCHOONER Type: sa...  2010  Van der Graaf
# 3  Price On Application\n \nThe current ATLANTIC ...  2010         Custom
# 4  A beautiful 43m Gulet classic luxury style bui...  2008   Custom Build
#
#                        model                     class  length    fuel  \
# 0          Baarda Zeegrundel           Barge sail boat    900m  Diesel
# 1                       2800  Sailing boats with cabin     83m  Diesel
# 2           Classic Schooner               Sloop boats  65,84m  Diesel
# 3  Van Der Graaf BV Schooner                   Cleaner  64,50m  Diesel
# 4                      Gulet            Sailing yachts  42,98m  Diesel
#
#             hull_material hull_shape hull_id_number hull_warranty
# 0                   Steel        NaN            NaN           NaN
# 1  Fiberglass / Polyester        NaN            NaN           NaN
# 2                   Steel        NaN            NaN           NaN
# 3                   Steel        NaN            NaN           NaN
# 4                    Wood        NaN            NaN           NaN

# %%
#Check out columns
data.columns
# Out:
# Index(['Unnamed: 0', 'name', 'price', 'location', 'offerer', 'link', 'id',
#        'img_url', 'listing_url', 'description', 'year', 'manufacturer',
#        'model', 'class', 'length', 'fuel', 'hull_material', 'hull_shape',
#        'hull_id_number', 'hull_warranty'],
#       dtype='object')

# %%
#Check missing values by column
missing = pd.concat([data.isnull().sum(), 100 * data.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count',ascending=False)
# Out:
#                 count          %
# hull_warranty    1891  98.643714
# hull_id_number   1790  93.375065
# hull_shape       1496  78.038602
# img_url           252  13.145540
# fuel              120   6.259781
# model               8   0.417319
# manufacturer        0   0.000000
# hull_material       0   0.000000
# length              0   0.000000
# class               0   0.000000
# Unnamed: 0          0   0.000000
# name                0   0.000000
# description         0   0.000000
# listing_url         0   0.000000
# id                  0   0.000000
# link                0   0.000000
# offerer             0   0.000000
# location            0   0.000000
# price               0   0.000000
# year                0   0.000000

# %%
#Overview of unique hull_warranty
unique_warranty = data['hull_warranty'].unique()
print(unique_warranty)
# Out:
# [nan '2 Jahre' '3 Jahre' '5 Jahre' '7 Jahre']

# %%
#Drop unnecessary columns
data = data.drop(columns=['Unnamed: 0','link', 'id','img_url','hull_id_number','hull_warranty'])

# %% [markdown]
# ## Let's focus on price first

# %%
data.head()
# Out:
#                                                 name         price  \
# 0  1976 Ketch Baarda Zeegrundel1976 Ketch Baarda ...      24.500 €
# 1                   1979 Dufour 28001979 Dufour 2800       9.900 €
# 2  2010 Van der Graaf Classic Schooner2010 Van de...  12.000.000 €
# 3  2010 Custom Van Der Graaf BV Schooner2010 Cust...  12.000.000 €
# 4     2008 Custom Build Gulet2008 Custom Build Gulet   5.000.000 €
#
#                               location                         offerer  \
# 0              Dinteloord, Niederlande                  Sealion Yachts
# 1              Greifswald, Deutschland              Privater Verkäufer
# 2  Contact De Valk Antibes, Frankreich               De Valk Group B.V
# 3                     IMPERIA, Italien  Bernard Gallay Yacht Brokerage
# 4                               Türkei                      Gino Group
#
#                                          listing_url  \
# 0  https://www.boot24.com/boot/1976-ketch-baarda-...
# 1  https://www.boot24.com/boot/1979-dufour-2800-8...
# 2  https://www.boot24.com/boot/2010-van-der-graaf...
# 3  https://www.boot24.com/boot/2010-custom-van-de...
# 4  https://www.boot24.com/boot/2008-custom-build-...
#
#                                          description  year   manufacturer  \
# 0  Algemeen: De Zeegrundel is een oorspronkelijk ...  1976          Ketch
# 1  Verkaufe eine gut erhaltene und ausgestattete ...  1979         Dufour
# 2  Model: VAN DER GRAAF CLASSIC SCHOONER Type: sa
#        '8.200 €', '100 €', '19.800 €', '74.628 €', '12.750 €', '9.800 €',
#        '37.400 €', '44.700 €', '11.374 €', '7.905 €', '11.500 €',
#        '4.944 €', '5.350 €', '5.900 €', '26.800 €', '24.490 €',
#        '10.900 €', '6.600 €', '74.077 €', '9.995 €', '25.300 €',
#        '2.600 €', '28.800 €', '5.250 €', '20.111 €', '8.013 €',
#        '22.463 €', '1.500 €', '1.950 €', '1.000 €', '25.999 €',
#        '36.303 €', '695 €', '1.900 €', '2.218 €', '11.349 €', '2.900 €',
#        '7.600 €', '4.890 €', '6.580 €', '126 €', '121.387 €', '5.520 €',
#        '950 €', '25 €', '4.520 €', '3.200 €', '3.600 €', '3.099 €',
#        '2.500 €'], dtype=object)

# %%
#Drop symbols in price column
data['price'] = data['price'].str.replace(' €', '')
data['price'] = data['price'].apply(lambda x: x.replace('.', ''))

#Drop "PreisaufAnfrage" from price column
data['price'] = data['price'].str.replace('Preis auf Anfrage', '')

#Convert price column to numeric 
#data['price'] = pd.to_numeric(raw_data['price'])

#Check type of price column
data['price'].dtype

#Check first few rows of price column
data['price'].head()
# Out:
# 0       24500
# 1        9900
# 2    12000000
# 3    12000000
# 4     5000000
# Name: price, dtype: object

# %%
unique_price = data['price'].unique()
unique_price
# Out:
# array(['24500', '9900', '12000000', '5000000', '', '7950000', '987000',
#        '3500000', '1300000', '500000', '3000000', '2800000', '2600000',
#        '1250000', '199500', '2500000', '4000000', '2890000', '700000',
#        '650000', '2650000', '1350000', '1600000', '2145000', '1200000',
#        '2000000', '1900000', '1450000', '1000000', '3600000', '950000',
#        '275000', '450000', '390000', '75000', '990000', '5800000',
#        '900000', '2900000', '590000', '350000', '740000', '995000',
#        '449000', '705000', '925000', '380000', '37000', '750000',
#        '850000', '1090000', '1990000', '550000', '437000', '1490000',
#        '749000', '579000', '1530083', '1500000', '1320000', '145000',
#        '1850000', '690000', '1299000', '465000', '2700000', '660450',
#        '1100000', '230075', '395000', '320000', '992000', '470000',
#        '389000', '1290000', '606933', '670000', '1240000', '168000',
#        '175000', '1215000', '460000', '185000', '689000', '154000',
#        '170000', '780000', '113452', '730000', '600000', '310000',
#        '295000', '335000', '220000', '1660000', '595000', '1695000',
#        '300000', '1750000', '400000', '425000', '150000', '440000',
#        '1783383', '480000', '375000', '495000', '240000', '599000',
#        '180000', '575000', '969000', '357500', '349000', '565250',
#        '490000', '625000', '1149000', '200000', '370000', '348000',
#        '329000', '296000', '1800000', '1400000', '685000', '771200',
#        '940000', '1080000', '842800', '298000', '290000', '115000',
#        '190000', '890000', '1086180', '870000', '398000', '279000',
#        '264000', '125000', '165000', '78500', '1700000', '45902',
#        '564000', '286000', '569000', '385000', '319000', '365000',
#        '297000', '439000', '698000', '340000', '1172044', '969053',
#        '1019035', '943551', '199000', '926500', '680000', '845000',
#        '1050000', '410000', '582000', '518090', '748331', '636927',
#        '515811', '725832', '304950', '315000', '17500', '430000',
#        '423000', '249500', '360000', '499000', '280000', '655000',
#        '289000', '250000', '285000', '566143', '476700', '453300',
#        '39500', '174000', '93000', '29900', '69900', '211570', '222700',
#        '68500', '89995', '38500', '31277', '18141', '68242', '71085',
#        '28428', '69995', '27000', '62900', '32500', '54500', '42651',
#        '41900', '790000', '37500', '9999', '146410', '28000', '163268',
#        '94500', '56000', '187850', '132000', '38670', '45438', '67104',
#        '41000', '59990', '134351', '203842', '59900', '153000', '138123',
#        '19500', '115737', '25900', '16500', '66304', '12000', '44500',
#        '137200', '49950', '34121', '34850', '24900', '30000', '33552',
#        '44073', '19600', '91703', '76772', '196195', '54025', '22690',
#        '40945', '18900', '99900', '4900', '112000', '14900', '79900',
#        '84500', '49995', '21000', '21500', '88888', '61900', '85500',
#        '168500', '130305', '146000', '136900', '33000', '51000', '86500',
#        '115570', '34500', '62500', '53500', '58900', '26900', '3500',
#        '58200', '24000', '8500', '69800', '17060', '11368', '18766',
#        '42082', '15866', '28377', '6500', '28700', '21900', '49831',
#        '46000', '62700', '152000', '128000', '121600', '13000', '12500',
#        '43500', '28900', '18000', '17300', '27800', '33333', '36900',
#        '44000', '44900', '32950', '47900', '62000', '20500', '52900',
#        '39808', '33950', '14000', '28434', '19904', '29931', '16000',
#        '22500', '22698', '8900', '53000', '19900', '72900', '24950',
#        '34000', '6000', '34950', '20473', '22742', '9950', '123500',
#        '16800', '23400', '16200', '29950', '17004', '28500', '4500',
#        '102345', '299999', '11900', '5500', '154500', '154602', '9000',
#        '27900', '7500', '53200', '32983', '21604', '15900', '2000',
#        '17055', '45489', '14500', '126800', '23900', '8000', '7900',
#        '14217', '9668', '4000', '6750', '1980', '23000', '32900', '43077',
#        '5800', '6800', '15', '44650', '9750', '50899', '15917', '36500',
#        '37800', '47450', '42840', '14250', '10000', '76000', '45980',
#        '51126', '9250', '48900', '19250', '15500', '14700', '18192',
#        '9500', '1706', '2275', '8530', '38850', '11800', '8200', '100',
#        '19800', '74628', '12750', '9800', '37400', '44700', '11374',
#        '7905', '11500', '4944', '5350', '5900', '26800', '24490', '10900',
#        '6600', '74077', '9995', '25300', '2600', '28800', '5250', '20111',
#        '8013', '22463', '1500', '1950', '1000', '25999', '36303', '695',
#        '1900', '2218', '11349', '2900', '7600', '4890', '6580', '126',
#        '121387', '5520', '950', '25', '4520', '3200', '3600', '3099',
#        '2500'], dtype=object)

# %%
#Convert price to number
data['price'] = data['price'].astype(str)
data['price'] = pd.to_numeric(data['price'].str.strip(), errors='coerce')
data['price'] = data['price'].fillna(0).astype(int)
data['price']
# Out:
# 0          24500
# 1           9900
# 2       12000000
# 3       12000000
# 4        5000000
#           ...
# 1912        3200
# 1913        3600
# 1914        3099
# 1915        7000
# 1916        2500
# Name: price, Length: 1917, dtype: int64

# %%
#Convert price from euro to US dollar
exchange_rate = 1.09
data['price'] = data['price'] * exchange_rate
data['price'] = data['price'].fillna(0).astype(int)

# %%
data.rename(columns={'price':'price_usd'}, inplace=True)

# %%
print(data[['price_usd']])
# Out:
#       price_usd
# 0         26705
# 1         10791
# 2      13080000
# 3      13080000
# 4       5450000
# ...         ...
# 1912       3488
# 1913       3924
# 1914       3377
# 1915       7630
# 1916       2725
#
# [1917 rows x 1 columns]

# %%
#Check out averages
data['price_usd'].describe().round(2)
# Out:
# count        1917.00
# mean       260456.71
# std        650665.07
# min             0.00
# 25%         38095.00
# 50%         96465.00
# 75%        260510.00
# max      13080000.00
# Name: price_usd, dtype: float64

# %%
# plot a bar chart of the class column
#plt.bar(raw_data['class'], data['price_usd'])

# add title and labels
#plt.title('Price & Class')
#plt.xlabel('class')
#plt.ylabel('price_usd')
#plt.xticks(rotation=90)

# show the plot
#plt.show()

#plot a bar chart of the class column
x = data['class']
y = data['price_usd']

# create a bar chart of the data
fig, ax = plt.subplots()
ax.bar(x, y)

# format y-axis ticks as currency
def currency(x, pos):
    return '${:,.2f}'.format(x)

formatter = ticker.FuncFormatter(currency)
ax.yaxis.set_major_formatter(formatter)

plt.title('Price & Class')
plt.xlabel('class')
plt.ylabel('price_usd')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ## Let's look at class, year, and length

# %%
data['class'].head()
# Out:
# 0             Barge sail boat
# 1    Sailing boats with cabin
# 2                 Sloop boats
# 3                     Cleaner
# 4              Sailing yachts
# Name: class, dtype: object

# %%
#Overview of unique year, class, length
unique_year = data['year'].unique()
print(unique_year)

unique_class = data['class'].unique()
print(unique_class)


unique_length = data['length'].unique()[:100] #only took first 100 values
print(unique_length)
# Out:
# [1976 1979 2010 2008 2025 2015 1986 1911 2007 1990 2004 1996 1910 2011
#  2018 1987 2005 2000 1992 2009 1998 1982 1968 2001 1997 1905 1985 2016
#  1957 2014 1984 1952 1993 2002 1966 1991 1938 1995 2024 1929 2006 2003
#  1994 1948 1935 1988 2017 1981 2012 1989 1973 1964 1983 1958 2021 1941
#  1914 1954 2023 1953 2022 1975 2013 2020 2019 1955 1978 1850 1977 1980
#  1999 1970 1930 1974 1900 1967 1933 1939 1971 1969 1972 1960 1959 1963
#  1936 1922 1926 1951 1962 1950 1928 1947 1917 1934 1946 1965 1961 1925
#  1931]
# ['Barge sail boat' 'Sailing boats with cabin' 'Sloop boats' 'Cleaner'
#  'Sailing yachts' 'Catamaran' 'Other (sailboats)'
#  'Catamarans and trimarans' 'Classic sailboats' 'Racer/cruiser sailboats'
#  'Deck saloon sailboats' 'Motor glider (sail)' 'Commercial ships (sails)'
#  'Gulets (Sail)' 'Ketch sailing boats' 'Daysailers' 'Cutter'
#  'Racer sailboats' 'Sailboats with a center cockpit'
#  'Dinghy sailing boats' 'Trimming' 'Dinghies and dinghy cruisers'
#  'Unspecified (Sailboats)' 'Performance sailboats']
# ['900m' '83m' '65,84m' '64,50m' '42,98m' '42,67m' '39,90m' '38,80m'
#  '38,10m' '38m' '37,50m' '37,49m' '36,88m' '36m' '35,50m' '35,40m' '35m'
#  '34,70m' '34,40m' '34m' '33,50m' '33,23m' '33m' '32,29m' '32m' '31,60m'
#  '31,09m' '31m' '30,48m' '30m' '29,65m' '29m' '28,80m' '28,45m' '28,40m'
#  '28,06m' '28m' '27,93m' '27,70m' '27m' '26,80m' '26,58m' '26,56m'
#  '26,33m' '25,91m' '25,13m' '25,10m' '25m' '24,80m' '24,64m' '24,40m'
#  '24,38m' '24,29m' '24,08m' '24m' '23,99m' '23,92m' '23,90m' '23,85m'
#  '23,80m' '23,72m' '23,50m' '23,22m' '23,20m' '23,17m' '23,16m' '23,15m'
#  '23m' '22,80m' '22,60m' '22,50m' '22,40m' '22,25m' '22,20m' '22m'
#  '21,95m' '21,90m' '21,88m' '21,82m' '21,80m' '21,76m' '21,75m' '21,60m'
#  '21,50m' '21,34m' '21,30m' '21,20m' '21,14m' '21,10m' '21m' '20,80m'
#  '20,76m' '20,73m' '20,70m' '20,50m' '20,44m' '20,42m' '20,32m' '20,30m'
#  '20,25m']

# %%
data['length'].describe()
# Out:
# count     1917
# unique     703
# top         9m
# freq        23
# Name: length, dtype: object

# %%
# Clean up length column
data['length'] = data['length'].str.replace('m', '')  # Remove 'm'
data['length'] = data['length'].str.replace(',', '.')  # Replace ',' with '.'
data['length'] = pd.to_numeric(data['length'], errors='coerce')  # Convert to numeric

# Convert lengths from meters to feet
data['length_ft'] = data['length'] * 3.28084

# Display the first few rows of the cleaned and converted 'length_ft' column
print(data['length_ft'].head())
# Out:
# 0    2952.756000
# 1     272.309720
# 2     216.010506
# 3     211.614180
# 4     141.010503
# Name: length_ft, dtype: float64

# %%
data['length_ft'].describe()
# Out:
# count    1917.000000
# mean       43.846381
# std        68.896103
# min         8.202100
# 25%        31.955382
# 50%        39.041996
# 75%        48.228348
# max      2952.756000
# Name: length_ft, dtype: float64

# %%
data.head()
# Out:
#                                                 name  price_usd  \
# 0  1976 Ketch Baarda Zeegrundel1976 Ketch Baarda ...      26705
# 1                   1979 Dufour 28001979 Dufour 2800      10791
# 2  2010 Van der Graaf Classic Schooner2010 Van de...   13080000
# 3  2010 Custom Van Der Graaf BV Schooner2010 Cust...   13080000
# 4     2008 Custom Build Gulet2008 Custom Build Gulet    5450000
#
#                               location                         offerer  \
# 0              Dinteloord, Niederlande                  Sealion Yachts
# 1              Greifswald, Deutschland              Privater Verkäufer
# 2  Contact De Valk Antibes, Frankreich               De Valk Group B.V
# 3                     IMPERIA, Italien  Bernard Gallay Yacht Brokerage
# 4                               Türkei                      Gino Group
#
#                                          listing_url  \
# 0  https://www.boot24.com/boot/1976-ketch-baarda-...
# 1  https://www.boot24.com/boot/1979-dufour-2800-8...
# 2  https://www.boot24.com/boot/2010-van-der-graaf...
# 3  https://www.boot24.com/boot/2010-custom-van-de...
# 4  https://www.boot24.com/boot/2008-custom-build-...
#
#                                          description  year   manufacturer  \
# 0  Algemeen: De Zeegrundel is een oorspronkelijk ...  1976          Ketch
# 1  Verkaufe eine gut erhaltene und ausgestattete ...  1979         Dufour
# 2  Model: VAN DER GRAAF CLASSIC SCHOONER Type: sa...  2010  Van der Graaf
# 3  Price On Application\n \nThe current ATLANTIC ...  2010         Custom
# 4  A beautiful 43m Gulet classic luxury style bui...  2008   Custom Build
#
#                        model                     class  length    fuel  \
# 0          Baarda Zeegrundel           Barge sail boat  900.00  Diesel
# 1                       2800  Sailing boats with cabin   83.00  Diesel
# 2           Classic Schooner               Sloop boats   65.84  Diesel
# 3  Van Der Graaf BV Schooner                   Cleaner   64.50  Diesel
# 4                      Gulet            Sailing yachts   42.98  Diesel
#
#             hull_material hull_shape    length_ft
# 0                   Steel        NaN  2952.756000
# 1  Fiberglass / Polyester        NaN   272.309720
# 2                   Steel        NaN   216.010506
# 3                   Steel        NaN   211.614180
# 4                    Wood        NaN   141.010503

# %%
data['class'].describe()
# Out:
# count               1917
# unique                24
# top       Sailing yachts
# freq                 621
# Name: class, dtype: object

# %%
class_counts = data['class'].value_counts()
print(class_counts)
# Out:
# Sailing yachts                     621
# Sloop boats                        395
# Daysailers                         292
# Racer/cruiser sailboats            117
# Other (sailboats)                  113
# Classic sailboats                   92
# Catamaran                           75
# Motor glider (sail)                 46
# Racer sailboats                     29
# Catamarans and trimarans            22
# Unspecified (Sailboats)             17
# Sailing boats with cabin            16
# Gulets (Sail)                       13
# Ketch sailing boats                 13
# Cutter                              11
# Sailboats with a center cockpit      8
# Dinghy sailing boats                 8
# Trimming                             7
# Dinghies and dinghy cruisers         7
# Barge sail boat                      5
# Deck saloon sailboats                4
# Cleaner                              3
# Performance sailboats                2
# Commercial ships (sails)             1
# Name: class, dtype: int64

# %% [markdown]
# ## Further exploration

# %%
data.T
# Out:
#                                                             0     \
# name           1976 Ketch Baarda Zeegrundel1976 Ketch Baarda ...
# price_usd                                                  26705
# location                                 Dinteloord, Niederlande
# offerer                                           Sealion Yachts
# listing_url    https://www.boot24.com/boot/1976-ketch-baarda-...
# description    Algemeen: De Zeegrundel is een oorspronkelijk ...
# year                                                        1976
# manufacturer                                               Ketch
# model                                          Baarda Zeegrundel
# class                                            Barge sail boat
# length                                                     900.0
# fuel                                                      Diesel
# hull_material                                              Steel
# hull_shape                                                   NaN
# length_ft                                               2952.756
#
#                                                             1     \
# name                            1979 Dufour 28001979 Dufour 2800
# price_usd                                                  10791
# location                                 Greifswald, Deutschland
# offerer                                       Privater Verkäufer
# listing_url    https://www.boot24.com/boot/1979-dufour-2800-8...
# description    Verkaufe eine gut erhaltene und ausgestattete ...
# year                                                        1979
# manufacturer                                              Dufour
# model                                                       2800
# class                                   Sailing boats with cabin
# length                                                      83.0
# fuel                                                      Diesel
# hull_material                             Fiberglass / Polyester
# hull_shape                                                   NaN
# length_ft                                              272.30972
#
#                                                             2     \
# name           2010 Van der Graaf Classic Schooner2010 Van de...
# price_usd                                               13080000
# location                     Contact De Valk Antibes, Frankreich
# offerer                                        De Valk Group B.V
# listing_url    https://www.boot24.com/boot/2010-van-der-graaf...
# description    Model: VAN DER GRAAF CLASSIC SCHOONER Type: sa...
# year                                                        2010
# manufacturer                                       Van der Graaf
# model                                           Classic Schooner
# class                                                Sloop boats
# length                                                     65.84
# fuel                                                      Diesel
# hull_material                                              Steel
# hull_shape                                                   NaN
# length_ft                                             216.010506
#
#                                                             3     \
# name           2010 Custom Van Der Graaf BV Schooner2010 Cust...
# price_usd                                               13080000
# location                                        IMPERIA, Italien
# offerer                           Bernard Gallay Yacht Brokerage
# listing_url    https://www.boot24.com/boot/2010-custom-van-de...
# description    Price On Application\n \nThe current ATLANTIC ...
# year                                                        2010
# manufacturer                                              Custom
# model                                  Van Der Graaf BV Schooner
# class                                                    Cleaner
# length                                                      64.5
# fuel                                                      Diesel
# hull_material                                              Steel
# hull_shape                                                   NaN
# length_ft                                              211.61418
#
#                                                             4     \
# name              2008 Custom Build Gulet2008 Custom Build Gulet
# price_usd                                                5450000
# location                                                  Türkei
# offerer                                               Gino Group
# listing_url    https://www.boot24.com/boot/2008-custom-build-...
# description    A beautiful 43m Gulet classic luxury style bui...
# year                                                        2008
# manufacturer                                        Custom Build
# model                                                      Gulet
# class                                             Sailing yachts
# length                                                     42.98
# fuel                                                      Diesel
# hull_material                                               Wood
# hull_shape                                                   NaN
# length_ft                                             141.010503
#
#                                                             5     \
# name                            2025 Sunreef 1402025 Sunreef 140
# price_usd                                                      0
# location                                           Gdansk, Polen
# offerer                                                S6 Marine
# listing_url    https://www.boot24.com/boot/2025-sunreef-140-8...
# description    The Sunreef 140 is a multihull superyacht boas...
# year                                                        2025
# manufacturer                                             Sunreef
# model                                                        140
# class                                                  Catamaran
# length                                                     42.67
# fuel                                                       Other
# hull_material                                          Composite
# hull_shape                                             Catamaran
# length_ft                                             139.993443
#
#                                                             6     \
# name                        2015 Bodrum Custom2015 Bodrum Custom
# price_usd                                                8665500
# location                            Sud de la france, Frankreich
# offerer                                    SARL YACHTSIDE MONACO
# listing_url    https://www.boot24.com/boot/2015-bodrum-custom...
# description    Make: BODRUM Model: Custom Year: 2015Mehr anze...
# year                                                        2015
# manufacturer                                              Bodrum
# model                                                     Custom
# class                                          Other (sailboats)
# length                                                      39.9
# fuel                                                      Diesel
# hull_material                                       Ferro-cement
# hull_shape                                                   NaN
# length_ft                                             130.905516
#
#                                                             7     \
# name           1986 Fjellstrand DSC Passenger Catamaran1986 F...
# price_usd                                                1075830
# location                     Contact De Valk Corfu, Griechenland
# offerer                                        De Valk Group B.V
# listing_url    https://www.boot24.com/boot/1986-fjellstrand-d...
# description    Model: FJELLSTRAND DSC PASSENGER CATAMARAN Typ...
# year                                                        1986
# manufacturer                                         Fjellstrand
# model                                    DSC Passenger Catamaran
# class                                   Catamarans and trimarans
# length                                                      38.8
# fuel                                                      Diesel
# hull_material                                           Aluminum
# hull_shape                                                 Other
# length_ft                                             127.296592
#
#                                                             8     \
# name           1911 William Fife & Sons 38Meter1911 William F...
# price_usd                                                3815000
# location                                  London, Greater London
# offerer                          Boats & Barcos Mediterráneos SL
# listing_url    https://www.boot24.com/boot/1911-william-fife-...
# description    Designed and built by William Fife, "Mariquita...
# year                                                        1911
# manufacturer                                        William Fife
# model                                             & Sons 38Meter
# class                                          Classic sailboats
# length                                                      38.1
# fuel                                                      Diesel
# hull_material                                               Wood
# hull_shape                                                   NaN
# length_ft                                             125.000004
#
#                                                             9     ...  \
# name                2007 Schooner Eldorado2007 Schooner Eldorado  ...
# price_usd                                                1417000  ...
# location                  Contact De Valk Amsterdam, Deutschland  ...
# offerer                                        De Valk Group B.V  ...
# listing_url    https://www.boot24.com/boot/2007-schooner-eldo...  ...
# description    Model: SCHOONER ELDORADO Type: sailing yacht L...  ...
# year                                                        2007  ...
# manufacturer                                            Schooner  ...
# model                                                   Eldorado  ...
# class                                                Sloop boats  ...
# length                                                      38.0  ...
# fuel                                                      Diesel  ...
# hull_material                                              Steel  ...
# hull_shape                                                   NaN  ...
# length_ft                                              124.67192  ...
#
#                                                             1907  \
# name                        1965 Flying Junior1965 Flying Junior
# price_usd                                                   1035
# location                                             Niederlande
# offerer                              Jachtbemiddeling Sneekerhof
# listing_url    https://www.boot24.com/boot/1965-flying-junior...
# description    Open sailboat with excellent sailing character...
# year                                                        1965
# manufacturer                                              Flying
# model                                                     Junior
# class                                          Other (sailboats)
# length                                                      4.03
# fuel                                                         NaN
# hull_material                             Fiberglass / Polyester
# hull_shape                                                   NaN
# length_ft                                              13.221785
#
#                                                             1908  \
# name           2021 unbekannt 12-fuß-dinghy2021 unbekannt 12-...
# price_usd                                                  13625
# location                                   Augsburg, Deutschland
# offerer                                       Privater Verkäufer
# listing_url    https://www.boot24.com/boot/2021-unbekannt-12-...
# description    Das Gesamtpaket umfasst: Rumpf (GFK) mit Holz-...
# year                                                        2021
# manufacturer                                           unbekannt
# model                                              12-fuß-dinghy
# class                               Dinghies and dinghy cruisers
# length                                                      3.67
# fuel                                                         NaN
# hull_material                                          Composite
# hull_shape                                                   NaN
# length_ft                                              12.040683
#
#                                                             1909  \
# name           2010 Teja wooden Boats 12-Fuß Dingi -VERKAUFT-...
# price_usd                                                  10791
# location                                     Alster, Deutschland
# offerer                                     Nordic Yachting e.K.
# listing_url    https://www.boot24.com/boot/2010-teja-wooden-b...
# description    Naturlackiertes 12-Fuß Dinghy von Teja Woodenb...
# year                                                        2010
# manufacturer                                   Teja wooden Boats
# model                                    12-Fuß Dingi -VERKAUFT-
# class                               Dinghies and dinghy cruisers
# length                                                      3.66
# fuel                                                         NaN
# hull_material                                               Wood
# hull_shape                                                   NaN
# length_ft                                              12.007874
#
#                                                             1910  \
# name                              1850 Topper 3401850 Topper 340
# price_usd                                                     27
# location                            Dinteloord (NL), Niederlande
# offerer                                          Bootveiling.com
# listing_url    https://www.boot24.com/boot/1850-topper-340-85...
# description    Een Topper in de online veiling. Iedereen kan ...
# year                                                        1850
# manufacturer                                              Topper
# model                                                        340
# class                                                Sloop boats
# length                                                       3.4
# fuel                                                         NaN
# hull_material                                    Other materials
# hull_shape                                                   NaN
# length_ft                                              11.154856
#
#                                                             1911  \
# name                2022 MiniCat 310 Sport2022 MiniCat 310 Sport
# price_usd                                                   4926
# location                                             Deutschland
# offerer                                          Steinkämper GbR
# listing_url    https://www.boot24.com/boot/2022-minicat-310-s...
# description    Jetzt in der neuen 2022er Version, 5 kg leicht...
# year                                                        2022
# manufacturer                                             MiniCat
# model                                                  310 Sport
# class                                          Other (sailboats)
# length                                                       3.1
# fuel                                                         NaN
# hull_material                                           Aluminum
# hull_shape                                                   NaN
# length_ft                                              10.170604
#
#                                                             1912  \
# name                        2022 MiniCat GUPPY2022 MiniCat GUPPY
# price_usd                                                   3488
# location                                             Deutschland
# offerer                                          Steinkämper GbR
# listing_url    https://www.boot24.com/boot/2022-minicat-guppy...
# description    Neues Modell Minicat GUPPY – kompakter geht es...
# year                                                        2022
# manufacturer                                             MiniCat
# model                                                      GUPPY
# class                                          Other (sailboats)
# length                                                       3.0
# fuel                                                         NaN
# hull_material                                           Aluminum
# hull_shape                                                   NaN
# length_ft                                                9.84252
#
#                                                             1913  \
# name           2022 Williams Jet Tenders Ersatzschlauch2022 W...
# price_usd                                                   3924
# location                            Worms , Rhineland-Palatinate
# offerer                                     Allegro Handels GmbH
# listing_url    https://www.boot24.com/boot/2022-williams-jet-...
# description    Ersatzschlauch für Schlauchboot Turbojet 285, ...
# year                                                        2022
# manufacturer                                Williams Jet Tenders
# model                                             Ersatzschlauch
# class                                          Other (sailboats)
# length                                                      2.89
# fuel                                                       Other
# hull_material                                      PVC (Plastic)
# hull_shape                                                   NaN
# length_ft                                               9.481628
#
#                                                             1914  \
# name                          2014 Bic Open Bic2014 Bic Open Bic
# price_usd                                                   3377
# location                                          Edersee, Hesse
# offerer                                Ship-Shop Rehbach-Edersee
# listing_url    https://www.boot24.com/boot/2014-bic-open-bic-...
# description    nur noch 2 Boote vorrätig Bj 2019\n Probesegel...
# year                                                        2014
# manufacturer                                                 Bic
# model                                                   Open Bic
# class                                             Sailing yachts
# length                                                      2.75
# fuel                                                         NaN
# hull_material                                    Other materials
# hull_shape                                                   NaN
# length_ft                                                9.02231
#
#                                                             1915  \
# name           1986 Sailboat Zuanelli 25 1986 Sailboat Zuanel...
# price_usd                                                   7630
# location                                                 Italien
# offerer                                          Pollini Nautica
# listing_url    https://www.boot24.com/boot/1986-sailboat-zuan...
# description          1986 Sailboat Zuanelli 25 nullMehr anzeigen
# year                                                        1986
# manufacturer                                Sailboat Zuanelli 25
# model                                                        NaN
# class                                          Other (sailboats)
# length                                                      2.52
# fuel                                                         NaN
# hull_material                                    Other materials
# hull_shape                                                 Other
# length_ft                                               8.267717
#
#                                                             1916
# name           1850 Botenkar Incl. 17 Stallingsbokken1850 Bot...
# price_usd                                                   2725
# location                            Dinteloord (NL), Niederlande
# offerer                                          Bootveiling.com
# listing_url    https://www.boot24.com/boot/1850-botenkar-incl...
# description    Een Botenkar Incl. 17 Stallingsbokken in de on...
# year                                                        1850
# manufacturer                                            Botenkar
# model                                   Incl. 17 Stallingsbokken
# class                                                Sloop boats
# length                                                       2.5
# fuel                                                         NaN
# hull_material                                              Steel
# hull_shape                                                   NaN
# length_ft                                                 8.2021
#
# [15 rows x 1917 columns]

# %%
#Check in with first few rows
data.head()
# Out:
#                                                 name  price_usd  \
# 0  1976 Ketch Baarda Zeegrundel1976 Ketch Baarda ...      26705
# 1                   1979 Dufour 28001979 Dufour 2800      10791
# 2  2010 Van der Graaf Classic Schooner2010 Van de...   13080000
# 3  2010 Custom Van Der Graaf BV Schooner2010 Cust...   13080000
# 4     2008 Custom Build Gulet2008 Custom Build Gulet    5450000
#
#                               location                         offerer  \
# 0              Dinteloord, Niederlande                  Sealion Yachts
# 1              Greifswald, Deutschland              Privater Verkäufer
# 2  Contact De Valk Antibes, Frankreich               De Valk Group B.V
# 3                     IMPERIA, Italien  Bernard Gallay Yacht Brokerage
# 4                               Türkei                      Gino Group
#
#                                          listing_url  \
# 0  https://www.boot24.com/boot/1976-ketch-baarda-...
# 1  https://www.boot24.com/boot/1979-dufour-2800-8...
# 2  https://www.boot24.com/boot/2010-van-der-graaf...
# 3  https://www.boot24.com/boot/2010-custom-van-de...
# 4  https://www.boot24.com/boot/2008-custom-build-...
#
#                                          description  year   manufacturer  \
# 0  Algemeen: De Zeegrundel is een oorspronkelijk ...  1976          Ketch
# 1  Verkaufe eine gut erhaltene und ausgestattete ...  1979         Dufour
# 2  Model: VAN DER GRAAF CLASSIC SCHOONER Type: sa...  2010  Van der Graaf
# 3  Price On Application\n \nThe current ATLANTIC ...  2010         Custom
# 4  A beautiful 43m Gulet classic luxury style bui...  2008   Custom Build
#
#                        model                     class  length    fuel  \
# 0          Baarda Zeegrundel           Barge sail boat  900.00  Diesel
# 1                       2800  Sailing boats with cabin   83.00  Diesel
# 2           Classic Schooner               Sloop boats   65.84  Diesel
# 3  Van Der Graaf BV Schooner                   Cleaner   64.50  Diesel
# 4                      Gulet            Sailing yachts   42.98  Diesel
#
#             hull_material hull_shape    length_ft
# 0                   Steel        NaN  2952.756000
# 1  Fiberglass / Polyester        NaN   272.309720
# 2                   Steel        NaN   216.010506
# 3                   Steel        NaN   211.614180
# 4                    Wood        NaN   141.010503

# %%
# Convert all to lowercase

data = data.applymap(lambda x: x.lower() if isinstance(x, str) else x)

# %%
#Look for values in hull_shape, hull_id_number, and hull_warranty
unique_hull_shape = data['hull_shape'].unique()
print(unique_hull_shape)
# Out:
# [nan 'catamaran' 'other' 'monohull' 'displacement' 'semi-displacement'
#  'planing' 'trimaran' 'deep vee' 'tunnel']

# %%
data['class'].unique()
# Out:
# array(['barge sail boat', 'sailing boats with cabin', 'sloop boats',
#        'cleaner', 'sailing yachts', 'catamaran', 'other (sailboats)',
#        'catamarans and trimarans', 'classic sailboats',
#        'racer/cruiser sailboats', 'deck saloon sailboats',
#        'motor glider (sail)', 'commercial ships (sails)', 'gulets (sail)',
#        'ketch sailing boats', 'daysailers', 'cutter', 'racer sailboats',
#        'sailboats with a center cockpit', 'dinghy sailing boats',
#        'trimming', 'dinghies and dinghy cruisers',
#        'unspecified (sailboats)', 'performance sailboats'], dtype=object)

# %%
data['hull_material'].unique()
# Out:
# array(['steel', 'fiberglass / polyester', 'wood', 'composite',
#        'ferro-cement', 'aluminum', 'other materials', 'pvc (plastic)'],
#       dtype=object)

# %%
data['fuel'].unique()
# Out:
# array(['diesel', 'other', nan, 'electric', 'gasoline'], dtype=object)

# %%
data.head()
# Out:
#                                                 name  price_usd  \
# 0  1976 ketch baarda zeegrundel1976 ketch baarda ...      26705
# 1                   1979 dufour 28001979 dufour 2800      10791
# 2  2010 van der graaf classic schooner2010 van de...   13080000
# 3  2010 custom van der graaf bv schooner2010 cust...   13080000
# 4     2008 custom build gulet2008 custom build gulet    5450000
#
#                               location                         offerer  \
# 0              dinteloord, niederlande                  sealion yachts
# 1              greifswald, deutschland              privater verkäufer
# 2  contact de valk antibes, frankreich               de valk group b.v
# 3                     imperia, italien  bernard gallay yacht brokerage
# 4                               türkei                      gino group
#
#                                          listing_url  \
# 0  https://www.boot24.com/boot/1976-ketch-baarda-...
# 1  https://www.boot24.com/boot/1979-dufour-2800-8...
# 2  https://www.boot24.com/boot/2010-van-der-graaf...
# 3  https://www.boot24.com/boot/2010-custom-van-de...
# 4  https://www.boot24.com/boot/2008-custom-build-...
#
#                                          description  year   manufacturer  \
# 0  algemeen: de zeegrundel is een oorspronkelijk ...  1976          ketch
# 1  verkaufe eine gut erhaltene und ausgestattete ...  1979         dufour
# 2  model: van der graaf classic schooner type: sa...  2010  van der graaf
# 3  price on application\n \nthe current atlantic ...  2010         custom
# 4  a beautiful 43m gulet classic luxury style bui...  2008   custom build
#
#                        model                     class  length    fuel  \
# 0          baarda zeegrundel           barge sail boat  900.00  diesel
# 1                       2800  sailing boats with cabin   83.00  diesel
# 2           classic schooner               sloop boats   65.84  diesel
# 3  van der graaf bv schooner                   cleaner   64.50  diesel
# 4                      gulet            sailing yachts   42.98  diesel
#
#             hull_material hull_shape    length_ft
# 0                   steel        NaN  2952.756000
# 1  fiberglass / polyester        NaN   272.309720
# 2                   steel        NaN   216.010506
# 3                   steel        NaN   211.614180
# 4                    wood        NaN   141.010503

# %%
# Drop columns

columns_to_drop = ['location', 'offerer', 'listing_url', 'description']
data = data.drop(columns=columns_to_drop, errors='ignore')

# %%
data.head()
# Out:
#                                                 name  price_usd  year  \
# 0  1976 ketch baarda zeegrundel1976 ketch baarda ...      26705  1976
# 1                   1979 dufour 28001979 dufour 2800      10791  1979
# 2  2010 van der graaf classic schooner2010 van de...   13080000  2010
# 3  2010 custom van der graaf bv schooner2010 cust...   13080000  2010
# 4     2008 custom build gulet2008 custom build gulet    5450000  2008
#
#     manufacturer                      model                     class  length  \
# 0          ketch          baarda zeegrundel           barge sail boat  900.00
# 1         dufour                       2800  sailing boats with cabin   83.00
# 2  van der graaf           classic schooner               sloop boats   65.84
# 3         custom  van der graaf bv schooner                   cleaner   64.50
# 4   custom build                      gulet            sailing yachts   42.98
#
#      fuel           hull_material hull_shape    length_ft
# 0  diesel                   steel        NaN  2952.756000
# 1  diesel  fiberglass / polyester        NaN   272.309720
# 2  diesel                   steel        NaN   216.010506
# 3  diesel                   steel        NaN   211.614180
# 4  diesel                    wood        NaN   141.010503

# %%
# Filter rows with missing values in the 'price_usd' column
missing_price = data[data['price_usd'].isnull()]
print(missing_price)
# Out:
# Empty DataFrame
# Columns: [name, price_usd, year, manufacturer, model, class, length, fuel, hull_material, hull_shape, length_ft]
# Index: []

# %%
#Check out numeric data
data.describe().T
# Out:
#             count           mean            std        min           25%  \
# price_usd  1917.0  260456.708399  650665.066367     0.0000  38095.000000
# year       1917.0    1996.285863      21.842210  1850.0000   1983.000000
# length     1917.0      13.364377      20.999531     2.5000      9.740000
# length_ft  1917.0      43.846381      68.896103     8.2021     31.955382
#
#                     50%            75%           max
# price_usd  96465.000000  260510.000000  1.308000e+07
# year        2000.000000    2012.000000  2.025000e+03
# length        11.900000      14.700000  9.000000e+02
# length_ft     39.041996      48.228348  2.952756e+03

# %%
#Find range of length_ft
length_range = data['length_ft'].max() - data['length_ft'].min()
print("length range:", length_range)
# Out:
# length range: 2944.5539

# %%
extra_long = (data['length_ft'] > 100).sum()
print("Number of rows with length over 100ft: ", extra_long)
# Out:
# Number of rows with length over 100ft:  35

# %%
#How does this affect price?
price_description = data['price_usd'].describe().to_frame()

# Format the values to have commas for thousands separator
price_description = price_description.applymap('{:,.2f}'.format)

print(price_description)
# Out:
#            price_usd
# count       1,917.00
# mean      260,456.71
# std       650,665.07
# min             0.00
# 25%        38,095.00
# 50%        96,465.00
# 75%       260,510.00
# max    13,080,000.00

# %%
#How many are really expensive? 
expensive = (data['price_usd'] > 5000000).sum()
print("Number of rows with prices over 5mil: ", expensive)
# Out:
# Number of rows with prices over 5mil:  5

# %%
#That's not too bad; how about 1mil?
expensive = (data['price_usd'] > 1000000).sum()
print("Number of rows with prices over 1mil: ", expensive)
# Out:
# Number of rows with prices over 1mil:  88

# %%
#What about under 1,000?
cheap = (data['price_usd'] < 1000).sum()
print("Number of rows with prices under 1,000: ", cheap)
# Out:
# Number of rows with prices under 1,000:  75

# %%
# What is the length of these boats?
cheap_length = data.loc[data['price_usd'] < 1000, 'length_ft']
cheap_length_df = pd.DataFrame({'Length (ft)': cheap_length})
print(cheap_length_df.head())
# Out:
#     Length (ft)
# 5    139.993443
# 34   100.000003
# 54    82.349084
# 63    79.986879
# 64    79.986879

# %%
cheap_length.describe()
# Out:
# count     75.000000
# mean      43.290903
# std       21.528721
# min       11.154856
# 25%       29.002626
# 50%       39.337272
# 75%       51.082679
# max      139.993443
# Name: length_ft, dtype: float64

# %%
#Reduce length_ft column to zero decimal points
data['length_ft'] = data['length_ft'].astype(int)
data['length_ft'].head()
# Out:
# 0    2952
# 1     272
# 2     216
# 3     211
# 4     141
# Name: length_ft, dtype: int64

# %% [markdown]
# ## Distribution Of Price By Length

# %%
#Calculate average price by legnth
data_price_means = data.groupby('length_ft')[['price_usd']].mean().round(2)
data_price_means.head()
# Out:
#            price_usd
# length_ft
# 8            5177.50
# 9            3596.33
# 10           4926.00
# 11             27.00
# 12          12208.00

# %%
#Plot price by length
(data_price_means.reindex(index=data_price_means.mean(axis=1)
    .sort_values(ascending=False)
    .index)
    .plot(kind='bar', figsize=(20, 5), title='Average price by length'))
plt.xlabel('Length (ft)')
# Out:
# Text(0.5, 0, 'Length (ft)')

# %%
data.head()
# Out:
#                                                 name  price_usd  year  \
# 0  1976 ketch baarda zeegrundel1976 ketch baarda ...      26705  1976
# 1                   1979 dufour 28001979 dufour 2800      10791  1979
# 2  2010 van der graaf classic schooner2010 van de...   13080000  2010
# 3  2010 custom van der graaf bv schooner2010 cust...   13080000  2010
# 4     2008 custom build gulet2008 custom build gulet    5450000  2008
#
#     manufacturer                      model                     class  length  \
# 0          ketch          baarda zeegrundel           barge sail boat  900.00
# 1         dufour                       2800  sailing boats with cabin   83.00
# 2  van der graaf           classic schooner               sloop boats   65.84
# 3         custom  van der graaf bv schooner                   cleaner   64.50
# 4   custom build                      gulet            sailing yachts   42.98
#
#      fuel           hull_material hull_shape  length_ft
# 0  diesel                   steel        NaN       2952
# 1  diesel  fiberglass / polyester        NaN        272
# 2  diesel                   steel        NaN        216
# 3  diesel                   steel        NaN        211
# 4  diesel                    wood        NaN        141

# %%
file_path = 'data_cleaned.csv'

# Save the DataFrame to a CSV file
data.to_csv(file_path, index=False)
